# %%
from bs4 import BeautifulSou

# %%
import requests

# %%
url="https://www.scrapethissite.com/pages/forms/?page_num=22"

# %%
url
# Out:
# 'https://www.scrapethissite.com/pages/forms/?page_num=22'

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.find("div") # find only first occurance
# Out:
# <div class="container">
# <div class="col-md-12">
# <ul class="nav nav-tabs">
# <li id="nav-homepage">
# <a class="nav-link hidden-sm hidden-xs" href="/">
# <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                 Scrape This Site
#                             </a>
# </li>
# <li id="nav-sandbox">
# <a class="nav-link" href="/pages/">
# <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                 Sandbox
#                             </a>
# </li>
# <li id="nav-lessons">
# <a class="nav-link" href="/lessons/">
# <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                 Lessons
#                             </a>
# </li>
# <li id="nav-faq">
# <a class="nav-link" href="/faq/">
# <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                 FAQ
#                             </a>
# </li>
# <li class="pull-right" id="nav-login">
# ...

# %%
soup.find_all("div") # to search all div
# Out:
# [<div class="container">
#  <div class="col-md-12">
#  <ul class="nav nav-tabs">
#  <li id="nav-homepage">
#  <a class="nav-link hidden-sm hidden-xs" href="/">
#  <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                  Scrape This Site
#                              </a>
#  </li>
#  <li id="nav-sandbox">
#  <a class="nav-link" href="/pages/">
#  <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                  Sandbox
#                              </a>
#  </li>
#  <li id="nav-lessons">
#  <a class="nav-link" href="/lessons/">
#  <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                  Lessons
#                              </a>
#  </li>
#  <li id="nav-faq">
#  <a class="nav-link" href="/faq/">
#  <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                  FAQ
#                              </a>
#  </li>
# ...

# %%
soup.find_all('div',class_='')  # to find all class
# Out:
# [<div id="page">
#  <section id="hockey">
#  <div class="container">
#  <div class="row">
#  <div class="col-md-12">
#  <h1>
#                              Hockey Teams: Forms, Searching and Pagination
#                              <small>25 items</small>
#  </h1>
#  <hr/>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-md-12">
#  <p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>
#  <hr/>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-md-6">
#  <p>
#  <i class="glyphicon glyphicon-education"></i> There are <a href="/lessons/">8 video lessons</a> that show you how to scrape this page.
# ...

# %%
soup.find_all('div',class_='col-md-12') # to search perticular class
# Out:
# [<div class="col-md-12">
#  <ul class="nav nav-tabs">
#  <li id="nav-homepage">
#  <a class="nav-link hidden-sm hidden-xs" href="/">
#  <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                  Scrape This Site
#                              </a>
#  </li>
#  <li id="nav-sandbox">
#  <a class="nav-link" href="/pages/">
#  <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                  Sandbox
#                              </a>
#  </li>
#  <li id="nav-lessons">
#  <a class="nav-link" href="/lessons/">
#  <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
#                                  Lessons
#                              </a>
#  </li>
#  <li id="nav-faq">
#  <a class="nav-link" href="/faq/">
#  <i class="glyphicon glyphicon-flag hidden-sm hidden-xs"></i>
#                                  FAQ
#                              </a>
#  </li>
#  <li class="pull-right" id="nav-login">
# ...

# %%
soup.find_all('p',class_='lead')
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>]

# %%
soup.find('p',class_='lead').text
# Out:
# '\n                            Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.\n                        '

# %%
soup.find('p',class_='lead').text.strip()
# Out:
# 'Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.'

# %%
soup.find_all('th')
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
url="https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue"

# %%
page=requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.text,'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of largest companies in the United States by revenue - Wikipedia
#   </title>
#   <script>
# ...

# %%
table=soup.find_all('table')[1]

# %%
table
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
soup.find('table',class_="wikitable sortable")
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
world_titles=table.find_all('th')

# %%
world_titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD millions)
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
world_table_titles=[title.text.strip() for title in world_titles]

# %%
world_table_titles
# Out:
# ['Rank',
#  'Name',
#  'Industry',
#  'Revenue (USD millions)',
#  'Revenue growth',
#  'Employees',
#  'Headquarters']

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=world_table_titles)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
column_data=table.find_all('tr')

# %%
column_data
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Revenue <br/>(USD millions)
#  </th>
#  <th>Revenue growth
#  </th>
#  <th>Employees
#  </th>
#  <th>Headquarters
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
#  </td>
#  <td><a href="/wiki/Retail" title="Retail">Retail</a>
#  </td>
#  <td style="text-align:center;">611,289
#  </td>
# ...

# %%
for row in column_data:
    row_data=row.find_all('td')
    individual_row_data=[data.text for data in row_data]
    print(individual_row_data)
# Out:
# []
# ['1\n', 'Walmart\n', 'Retail\n', '611,289\n', '  6.7%\n', '2,100,000\n', 'Bentonville, Arkansas\n']
# ['2\n', 'Amazon\n', 'Retail and cloud computing\n', '513,983\n', '  9.4%\n', '1,540,000\n', 'Seattle, Washington\n']
# ['3\n', 'ExxonMobil\n', 'Petroleum industry\n', '413,680\n', '  44.8%\n', '62,000\n', 'Spring, Texas\n']
# ['4\n', 'Apple\n', 'Electronics industry\n', '394,328\n', '  7.8%\n', '164,000\n', 'Cupertino, California\n']
# ['5\n', 'UnitedHealth Group\n', 'Healthcare\n', '324,162\n', '  12.7%\n', '400,000\n', 'Minnetonka, Minnesota\n']
# ['6\n', 'CVS Health\n', 'Healthcare\n', '322,467\n', '  10.4%\n', '259,500\n', 'Woonsocket, Rhode Island\n']
# ['7\n', 'Berkshire Hathaway\n', 'Conglomerate\n', '302,089\n', '  9.4%\n', '383,000\n', 'Omaha, Nebraska\n']
# ['8\n', 'Alphabet\n', 'Technology and cloud computing\n', '282,836\n', '  9.8%\n', '156,000\n', 'Mountain View, California\n']
# ...

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text for data in row_data]
    length=len(df)
    df.loc[length]= individual_row_data

# %%
df
# Out:
#      Rank                        Name                      Industry  \
# 0     1\n                   Walmart\n                      Retail\n
# 1     2\n                    Amazon\n  Retail and cloud computing\n
# 2     3\n                ExxonMobil\n          Petroleum industry\n
# 3     4\n                     Apple\n        Electronics industry\n
# 4     5\n        UnitedHealth Group\n                  Healthcare\n
# ..    ...                         ...                           ...
# 95   96\n                  Best Buy\n                      Retail\n
# 96   97\n      Bristol-Myers Squibb\n     Pharmaceutical industry\n
# 97   98\n           United Airlines\n                     Airline\n
# 98   99\n  Thermo Fisher Scientific\n      Laboratory instruments\n
# 99  100\n                  Qualcomm\n                  Technology\n
#
#    Revenue (USD millions) Revenue growth    Employees  \
# 0               611,289\n         6.7%\n  2,100,000\n
# ...

# %%
df.to_csv(r'data.csv')

# %% [markdown]
# # Scrapping the second table

# %%
soup.find('table', class_="wikitable sortable jquery-tablesorter")

# %%
table2=soup.find_all('table')[2]

# %%
table2
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD billions)
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Cargill" title="Cargill">Cargill</a>
# </td>
# <td>Food industry
# </td>
# <td style="text-align:center;">165
# </td>
# <td style="text-align:center;">155,000
# </td>
# <td><a href="/wiki/Minnetonka,_Minnesota" title="Minnetonka, Minnesota">Minnetonka, Minnesota</a>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><a href="/wiki/Koch_Industries" title="Koch Industries">Koch Industries</a>
# </td>
# <td>Conglomerate
# </td>
# <td style="text-align:center;">125
# </td>
# <td style="text-align:center;">120,000
# </td>
# <td><a href="/wiki/Wichita,_Kansas" title="Wichita, Kansas">Wichita, Kansas</a>
# </td></tr>
# <tr>
# <td>3
# </td>
# ...

# %%
column_title=table2.find_all('th')

# %%
column_title
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD billions)
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
column_table_titles=[title.text.strip() for title in column_title]

# %%
column_table_titles
# Out:
# ['Rank',
#  'Name',
#  'Industry',
#  'Revenue (USD billions)',
#  'Employees',
#  'Headquarters']

# %%
import pandas as pd

# %%
dataset=pd.DataFrame(columns=column_table_titles)

# %%
dataset
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD billions), Employees, Headquarters]
# Index: []

# %%
column_data=table2.find_all('tr')

# %%
column_data
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Revenue <br/>(USD billions)
#  </th>
#  <th>Employees
#  </th>
#  <th>Headquarters
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Cargill" title="Cargill">Cargill</a>
#  </td>
#  <td>Food industry
#  </td>
#  <td style="text-align:center;">165
#  </td>
#  <td style="text-align:center;">155,000
#  </td>
#  <td><a href="/wiki/Minnetonka,_Minnesota" title="Minnetonka, Minnesota">Minnetonka, Minnesota</a>
#  </td></tr>,
#  <tr>
#  <td>2
#  </td>
#  <td><a href="/wiki/Koch_Industries" title="Koch Industries">Koch Industries</a>
#  </td>
#  <td>Conglomerate
#  </td>
#  <td style="text-align:center;">125
#  </td>
#  <td style="text-align:center;">120,000
#  </td>
#  <td><a href="/wiki/Wichita,_Kansas" title="Wichita, Kansas">Wichita, Kansas</a>
#  </td></tr>,
#  <tr>
#  <td>3
#  </td>
# ...

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    print(individual_row_data)
# Out:
# ['1', 'Cargill', 'Food industry', '165', '155,000', 'Minnetonka, Minnesota']
# ['2', 'Koch Industries', 'Conglomerate', '125', '120,000', 'Wichita, Kansas']
# ['3', 'Publix Super Markets', 'Retail', '48', '230,000', 'Winter Haven, Florida']
# ['4', 'Mars, Incorporated', 'Food industry', '45', '140,000', 'McLean, Virginia']
# ['5', 'Pilot Corporation', 'Petroleum industry and Retail', '41.9', '30,000', 'Knoxville, Tennessee']
# ['6', 'H-E-B', 'Retail', '38.9', '145,000', 'San Antonio, Texas']
# ['7', 'Reyes Holdings', 'Wholesaling', '35.3', '33,000', 'Rosemont, Illinois']
# ['8', 'C&S Wholesale Grocers', 'Wholesaling', '33', '14,000', 'Keene, New Hampshire']
# ['9', 'Enterprise Holdings', 'Car rental', '30', '80,000', 'Clayton, Missouri']
# ['10', "Love's", 'Petroleum industry and Retail', '25.5', '38,000', 'Oklahoma City, Oklahoma']

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    length=len(dataset)
    dataset.loc[length]=individual_row_data

# %%
dataset
# Out:
#   Rank                   Name                       Industry  \
# 0    1                Cargill                  Food industry
# 1    2        Koch Industries                   Conglomerate
# 2    3   Publix Super Markets                         Retail
# 3    4     Mars, Incorporated                  Food industry
# 4    5      Pilot Corporation  Petroleum industry and Retail
# 5    6                  H-E-B                         Retail
# 6    7         Reyes Holdings                    Wholesaling
# 7    8  C&S Wholesale Grocers                    Wholesaling
# 8    9    Enterprise Holdings                     Car rental
# 9   10                 Love's  Petroleum industry and Retail
#
#   Revenue (USD billions) Employees             Headquarters
# 0                    165   155,000    Minnetonka, Minnesota
# 1                    125   120,000          Wichita, Kansas
# 2                     48   230,000    Winter Haven, Florida
# ...

# %%
dataset.to_csv('data2.csv')

# %% [markdown]
# # Scrapping third table

# %%
soup.find('table',class_='wikitable sortable jquery-tablesorter')

# %%
table3=soup.find_all('table')[3]

# %%
table3
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Profits<br/>(USD millions)
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Apple_Inc." title="Apple Inc.">Apple</a>
# </td>
# <td>Electronics
# </td>
# <td style="text-align:center;">99,803
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><a href="/wiki/Microsoft" title="Microsoft">Microsoft</a>
# </td>
# <td>Technology
# </td>
# <td style="text-align:center;">72,738
# </td></tr>
# <tr>
# <td>3
# </td>
# <td><a href="/wiki/Alphabet_Inc." title="Alphabet Inc.">Alphabet</a>
# </td>
# <td>Technology
# </td>
# <td style="text-align:center;">59,972
# </td></tr>
# <tr>
# <td>5
# </td>
# <td><a href="/wiki/ExxonMobil" title="ExxonMobil">ExxonMobil</a>
# </td>
# <td>Petroleum industry
# </td>
# <td style="text-align:center;">55,740
# </td></tr>
# <tr>
# <td>6
# </td>
# <td><a href="/wiki/JPMorgan_Chase" title="JPMorgan Chase">JPMorgan Chase</a>
# ...

# %%
column_heading=table3.find_all('th')

# %%
column_heading
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Profits<br/>(USD millions)
#  </th>]

# %%
column_table_heading=[heading.text.strip() for heading in column_heading]

# %%
column_table_heading
# Out:
# ['Rank', 'Name', 'Industry', 'Profits(USD millions)']

# %%
import pandas as pd

# %%
dataframe=pd.DataFrame(columns=column_table_heading)

# %%
dataframe
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Profits(USD millions)]
# Index: []

# %%
column_data=table3.find_all('tr')

# %%
column_data
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Profits<br/>(USD millions)
#  </th></tr>,
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Apple_Inc." title="Apple Inc.">Apple</a>
#  </td>
#  <td>Electronics
#  </td>
#  <td style="text-align:center;">99,803
#  </td></tr>,
#  <tr>
#  <td>2
#  </td>
#  <td><a href="/wiki/Microsoft" title="Microsoft">Microsoft</a>
#  </td>
#  <td>Technology
#  </td>
#  <td style="text-align:center;">72,738
#  </td></tr>,
#  <tr>
#  <td>3
#  </td>
#  <td><a href="/wiki/Alphabet_Inc." title="Alphabet Inc.">Alphabet</a>
#  </td>
#  <td>Technology
#  </td>
#  <td style="text-align:center;">59,972
#  </td></tr>,
#  <tr>
#  <td>5
#  </td>
#  <td><a href="/wiki/ExxonMobil" title="ExxonMobil">ExxonMobil</a>
#  </td>
#  <td>Petroleum industry
#  </td>
#  <td style="text-align:center;">55,740
#  </td></tr>,
#  <tr>
#  <td>6
#  </td>
#  <td><a href="/wiki/JPMorgan_Chase" title="JPMorgan Chase">JPMorgan Chase</a>
#  </td>
# ...

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    print(individual_row_data)
# Out:
# ['1', 'Apple', 'Electronics', '99,803']
# ['2', 'Microsoft', 'Technology', '72,738']
# ['3', 'Alphabet', 'Technology', '59,972']
# ['5', 'ExxonMobil', 'Petroleum industry', '55,740']
# ['6', 'JPMorgan Chase', 'Financials', '37,676']
# ['7', 'Chevron Corporation', 'Petroleum industry', '35,465']
# ['8', 'Pfizer', 'Pharmaceutical industry', '31,372']
# ['9', 'Bank of America', 'Financials', '27,528']
# ['10', 'Meta Platforms', 'Technology', '23,200']

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    length=len(dataframe)
    dataframe.loc[length]=individual_row_data

# %%
dataframe
# Out:
#   Rank                 Name                 Industry Profits(USD millions)
# 0    1                Apple              Electronics                99,803
# 1    2            Microsoft               Technology                72,738
# 2    3             Alphabet               Technology                59,972
# 3    5           ExxonMobil       Petroleum industry                55,740
# 4    6       JPMorgan Chase               Financials                37,676
# 5    7  Chevron Corporation       Petroleum industry                35,465
# 6    8               Pfizer  Pharmaceutical industry                31,372
# 7    9      Bank of America               Financials                27,528
# 8   10       Meta Platforms               Technology                23,200

# %%
dataframe.to_csv('data3.csv')

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    df.to_excel(writer, sheet_name='Sheet1')
    dataset.to_excel(writer, sheet_name='Sheet2')
    dataframe.to_excel(writer, sheet_name='Sheet3')
